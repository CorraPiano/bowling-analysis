# %%
import cv2
from pathlib import Path
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Import video 2

# %%
# Define the relative path to the video file
notebook_dir = Path().resolve()
project_root = notebook_dir.parent.parent
video_path = project_root / "data" / "recording_2" / "Recording_2_normal_speed.mp4"
video_path = str(video_path)

# Load the video
cap = cv2.VideoCapture(video_path)

# Check
print(f"Opened: {cap.isOpened()}, FPS: {cap.get(cv2.CAP_PROP_FPS)}, Total Frames: {cap.get(cv2.CAP_PROP_FRAME_COUNT)}")
# Out:
# Opened: True, FPS: 59.94005994005994, Total Frames: 276.0

# %% [markdown]
# Get frame 100

# %%
# Set frame position
cap.set(cv2.CAP_PROP_POS_FRAMES, 100)
ret, colored_image = cap.read()
if not ret:
    print("Failed to read the frame")
    cap.release()
    exit()

# grayscale
image = cv2.cvtColor(colored_image, cv2.COLOR_BGR2GRAY)

# Show the image
plt.imshow(image, cmap='gray')
plt.title('Frame 100')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Get points

# %%
# Create a copy of the original image
image_with_point = np.copy(image)

# Draw a circle at the point
cv2.circle(image_with_point, (1520, 950), radius=5, color=(0,0,0), thickness=-1)

# Display the image with the point
plt.imshow(image_with_point, cmap='gray')
plt.title('Immagine con il Punto')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Points:\
# bottom left:  600,940\
# bottom right: 1520,950\
# top right: 1382,500\
# top left: 1000, 490

# %%
points = np.array([
    [600, 940, 1],    # bottom left
    [1520, 950, 1],   # bottom right
    [1382, 500, 1],   # top right
    [1000, 490, 1]    # top left
])
print(points)
data_path = project_root / "data" / "auxiliary_data" / "lane_points" / "lane_points_2_frame_100.csv"
np.savetxt(data_path, points, delimiter=",", header="x,y,z", comments='')
print(f"Points saved to {data_path}")
# Out:
# [[ 600  940    1]
#  [1520  950    1]
#  [1382  500    1]
#  [1000  490    1]]
# Points saved to C:\Users\miche\OneDrive\Documenti\GitHub\bowling-analysis\data\auxiliary_data\lane_points\lane_points_2_frame_1.csv

# %% [markdown]
# Get frame 50

# %%
# Set frame position
cap.set(cv2.CAP_PROP_POS_FRAMES, 50)
ret, colored_image = cap.read()
if not ret:
    print("Failed to read the frame")
    cap.release()
    exit()

# grayscale
image = cv2.cvtColor(colored_image, cv2.COLOR_BGR2GRAY)

# Show the image
plt.imshow(image, cmap='gray')
plt.title('Frame 50')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Get points

# %%
# Create a copy of the original image
image_with_point = np.copy(image)

# Draw a circle at the point
cv2.circle(image_with_point, (1396, 460), radius=5, color=(255,0,0), thickness=-1)

# Display the image with the point
plt.imshow(image_with_point, cmap='gray')
plt.title('Immagine con il Punto')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Points:\
# bottom left:  592,900\
# bottom right: 1530,910\
# top right: 1396,460\
# top left: 1000,450

# %%
points_frame_50 = np.array([
    [592, 900, 1],    # bottom left
    [1530, 910, 1],   # bottom right
    [1396, 460, 1],   # top right
    [1000, 450, 1]    # top left
])
print(points_frame_50)

data_path = project_root / "data" / "auxiliary_data" / "lane_points" / "lane_points_2_frame_50.csv"
np.savetxt(data_path, points_frame_50, delimiter=",", header="x,y,z", comments='')
print(f"Points saved to {data_path}")
# Out:
# [[ 592  900    1]
#  [1530  910    1]
#  [1396  460    1]
#  [1000  450    1]]
# Points saved to C:\Users\miche\OneDrive\Documenti\GitHub\bowling-analysis\data\auxiliary_data\lane_points\lane_points_2_frame_50.csv

# %% [markdown]
# Get frame 150

# %%
# Set frame position
cap.set(cv2.CAP_PROP_POS_FRAMES, 150)
ret, colored_image = cap.read()
if not ret:
    print("Failed to read the frame")
    cap.release()
    exit()

# grayscale
image = cv2.cvtColor(colored_image, cv2.COLOR_BGR2GRAY)

# Show the image
plt.imshow(image, cmap='gray')
plt.title('Frame 150')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Get Points

# %%
# Create a copy of the original image
image_with_point = np.copy(image)

# Draw a circle at the point
cv2.circle(image_with_point, (1500, 920), radius=5, color=(0,0,0), thickness=-1)

# Display the image with the point
plt.imshow(image_with_point, cmap='gray')
plt.title('Immagine con il Punto')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Points:\
# bottom left: 580,912 \
# bottom right: 1500,920\
# top right: 1363,470\
# top left: 970,470

# %%
# Combine the points from previous frames
points_frame_150 = np.array([
    [580, 912, 1],    # bottom left
    [1500, 920, 1],   # bottom right
    [1363, 470, 1],   # top right
    [970, 470, 1]     # top left
])

# Save the combined points to a CSV file
data_path = project_root / "data" / "auxiliary_data" / "lane_points" / "lane_points_2_frame_150.csv"
np.savetxt(data_path, points_frame_150, delimiter=",", header="x,y,z", comments='')
print(f"All points saved to {data_path}")
# Out:
# All points saved to C:\Users\miche\OneDrive\Documenti\GitHub\bowling-analysis\data\auxiliary_data\lane_points\lane_points_2_frame_150.csv
