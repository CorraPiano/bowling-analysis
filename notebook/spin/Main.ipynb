# %% [markdown]
# # Main code to run the **Spin Detection**

# %%
from pathlib import Path

# %% [markdown]
# ### `spin` - Spin detection

# %%
VIDEO_NUM = "5"
PROJECT_ROOT = Path().resolve().parent.parent

# %%
INPUT_VIDEO_PATH = str(PROJECT_ROOT / "data" / f"recording_{VIDEO_NUM}" / f"Recording_{VIDEO_NUM}.mp4")
INPUT_CSV_PATH = str(PROJECT_ROOT / "data" / "auxiliary_data" / "circle_positions" / f"Adjusted_positions_new_{VIDEO_NUM}.csv")
OUTPUT_CSV_PATH = str(PROJECT_ROOT / "notebook" / "spin" / "intermediate_data" / f"Rotation_data_{VIDEO_NUM}.csv")

# %run -i ~/projects/IACV_project/bowling-analysis/notebook/spin/Detection.py
# Out:
# Saved rotation data to /home/davic/projects/IACV_project/bowling-analysis/notebook/spin/intermediate_data/Rotation_data_7.csv

# %% [markdown]
# PROBLEM: still problems with `recording_5`, using `Spin_6` it works but the rad/s are not good, with `Spin_7` the rad/s are good but the video not

# %% [markdown]
# ### `spin` - Post-processing

# %%
INPUT_CSV_PATH = str(PROJECT_ROOT / "notebook" / "spin" / "intermediate_data" / f"Rotation_data_{VIDEO_NUM}.csv")
OUTPUT_CSV_PATH = str(PROJECT_ROOT / "notebook" / "spin" / "intermediate_data" / f"Rotation_data_processed_{VIDEO_NUM}.csv")

# %run -i ~/projects/IACV_project/bowling-analysis/notebook/spin/Post-processing.py
# Out:
# Saved rotation data to /home/davic/projects/IACV_project/bowling-analysis/notebook/spin/intermediate_data/Rotation_data_processed_TEST_5.csv

# %% [markdown]
# ### `spin` - Video creation

# %% [markdown]
# IMPORTANT: here I also need to fill the missing frames

# %%
video_path = str(PROJECT_ROOT / "data" / f"recording_{VIDEO_NUM}" / f"Recording_{VIDEO_NUM}.mp4")
input_data_path = str(PROJECT_ROOT / "notebook" / "spin" / "intermediate_data" / f"Rotation_data_processed_{VIDEO_NUM}.csv")
output_path_video = str(PROJECT_ROOT / "data" / f"recording_{VIDEO_NUM}" / "Rotating_sphere.mp4")

# %run -i ~/projects/IACV_project/bowling-analysis/notebook/spin/Video_creation.py
# Out:
# Starting spin detection for video 5...
# Video saved to /home/davic/projects/IACV_project/bowling-analysis/data/recording_5/Rotating_sphere.mp4
# Total runtime of Lane Detection: 12.25 seconds
