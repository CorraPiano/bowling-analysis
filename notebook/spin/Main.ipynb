# %% [markdown]
# # Main code to run the **Spin Detection**

# %%
from pathlib import Path

# %% [markdown]
# ### `spin` - Spin detection

# %%
VIDEO_NUM = "5"
PROJECT_ROOT = Path().resolve().parent.parent

# %%
INPUT_VIDEO_PATH = str(PROJECT_ROOT / "data" / f"recording_{VIDEO_NUM}" / f"Recording_{VIDEO_NUM}.mp4")
INPUT_CSV_PATH = str(PROJECT_ROOT / "data" / "auxiliary_data" / "circle_positions" / f"Adjusted_positions_new_{VIDEO_NUM}.csv")
OUTPUT_CSV_PATH = str(PROJECT_ROOT / "notebook" / "spin" / "intermediate_data" / f"Rotation_datassss_{VIDEO_NUM}.csv")

# %run -i ~/projects/IACV_project/bowling-analysis/notebook/spin/Detection_copy.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/projects/IACV_project/bowling-analysis/notebook/spin/Detection_copy.py:181
#     169 # ==============================================================================
#     170 #                                   MAIN FUNCTION
#     171 # ==============================================================================
#     173 if __name__ == "__main__":
#     174
#     175     #VIDEO_NUMBER = "7"
#    (...)
#     178     #INPUT_CSV_PATH = str(PROJECT_ROOT / "data" / "auxiliary_data" / "circle_positions" / f"Adjusted_positions_new_{VIDEO_NUMBER}.csv")
#     179     #OUTPUT_CSV_PATH = str(PROJECT_ROOT / "notebook" / "spin" / "intermediate_data" / f"Rotation_data_{VIDEO_NUMBER}.csv")
# --> 181     spin_detection(INPUT_VIDEO_PATH, INPUT_CSV_PATH, OUTPUT_CSV_PATH)
#
# ...

# %% [markdown]
# PROBLEM: it is not the same

# %% [markdown]
# ### `spin` - Post-processing

# %%
INPUT_CSV_PATH = str(PROJECT_ROOT / "notebook" / "spin" / "intermediate_data" / f"Rotation_data_TEST_{VIDEO_NUM}.csv")
OUTPUT_CSV_PATH = str(PROJECT_ROOT / "notebook" / "spin" / "intermediate_data" / f"Rotation_data_processed_TEST_{VIDEO_NUM}.csv")

# %run -i ~/projects/IACV_project/bowling-analysis/notebook/spin/Post-processing.py
# Out:
# Saved rotation data to /home/davic/projects/IACV_project/bowling-analysis/notebook/spin/intermediate_data/Rotation_data_processed_TEST1_5.csv

# %% [markdown]
# ### `spin` - Video creation

# %% [markdown]
# IMPORTANT: here I also need to fill the missing frames

# %%
video_path = str(PROJECT_ROOT / "data" / f"recording_{VIDEO_NUM}" / f"Recording_{VIDEO_NUM}.mp4")
input_data_path = str(PROJECT_ROOT / "notebook" / "spin" / "intermediate_data" / f"Rotation_data_processed_TEST_{VIDEO_NUM}.csv")
output_path_video = str(PROJECT_ROOT / "data" / f"recording_{VIDEO_NUM}" / "Rotating_sphere_TEST.mp4")

# %run -i ~/projects/IACV_project/bowling-analysis/notebook/spin/Video_creation.py
# Out:
# Starting spin detection for video 5...
# Video saved to /home/davic/projects/IACV_project/bowling-analysis/data/recording_5/Rotating_sphere_TEST.mp4
# Total runtime of Lane Detection: 13.88 seconds
